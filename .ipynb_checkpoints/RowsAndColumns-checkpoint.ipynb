# %%
import pandas as pd

# %%
people={ 'first' : ['Jane','John','Dharani'],
        'last':['Doe','Doe','Meka'],
        'email':['Jane@email.com','John@gmail.com','Dharani@email.com']}

# %%
df1=pd.DataFrame(people)

# %%
df1
# Out:
#      first  last              email
# 0     Jane   Doe     Jane@email.com
# 1     John   Doe     John@gmail.com
# 2  Dharani  Meka  Dharani@email.com

# %%
df1.loc[1,'last']='Smith'

# %%
df1
# Out:
#      first   last              email
# 0     Jane    Doe     Jane@email.com
# 1     John  Smith     John@gmail.com
# 2  Dharani   Meka  Dharani@email.com

# %%
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df1.columns = ['first_name', 'last_name','email']

# %%
df1
# Out:
#   first_name last_name              email
# 0       Jane       Doe     Jane@email.com
# 1       John     Smith     John@gmail.com
# 2    Dharani      Meka  Dharani@email.com

# %%
df1.columns = [x.upper() for x in df1.columns]

# %%
df1
# Out:
#   FIRST_NAME LAST_NAME              EMAIL
# 0       Jane       Doe     Jane@email.com
# 1       John     Smith     John@gmail.com
# 2    Dharani      Meka  Dharani@email.com

# %%
df1.columns = df1.columns.str.replace('_',' ')

# %%
df1
# Out:
#   FIRST NAME LAST NAME              EMAIL
# 0       Jane       Doe     Jane@email.com
# 1       John     Smith     John@gmail.com
# 2    Dharani      Meka  Dharani@email.com

# %%
df1.columns = df1.columns.str.replace(' ','_')

# %%
df1
# Out:
#   FIRST_NAME LAST_NAME              EMAIL
# 0       Jane       Doe     Jane@email.com
# 1       John     Smith     John@gmail.com
# 2    Dharani      Meka  Dharani@email.com

# %%
df1.columns=[x.lower() for x in df1.columns]

# %%
df1.rename(columns={'first_name':'first','last_name':'last'}, inplace=True)

# %%
df1
# Out:
#      first   last              email
# 0     Jane    Doe     Jane@email.com
# 1     John  Smith     John@gmail.com
# 2  Dharani   Meka  Dharani@email.com

# %%
df1.loc[1,['last','email']]=['Doe','JohnD@email.com']

# %%
df1
# Out:
#      first  last              email
# 0     Jane   Doe     Jane@email.com
# 1     John   Doe    JohnD@email.com
# 2  Dharani  Meka  Dharani@email.com

# %%
df1.loc[1,'last']='Smith'

# %%
df1
# Out:
#      first   last              email
# 0     Jane    Doe     Jane@email.com
# 1     John  Smith    JohnD@email.com
# 2  Dharani   Meka  Dharani@email.com

# %%
df1.at[1,'last']='Doe'

# %%
df1
# Out:
#      first  last              email
# 0     Jane   Doe     Jane@email.com
# 1     John   Doe    JohnD@email.com
# 2  Dharani  Meka  Dharani@email.com

# %%
df1['first']+' '+df1['last']
# Out:
# 0        Jane Doe
# 1        John Doe
# 2    Dharani Meka
# dtype: object

# %%
df1
# Out:
#      first  last              email     full_name
# 0     Jane   Doe     Jane@email.com      Jane Doe
# 1     John   Doe    JohnD@email.com      John Doe
# 2  Dharani  Meka  Dharani@email.com  Dharani Meka

# %%
df1.drop(columns=['first','last'],inplace=True)

# %%
df1
# Out:
#                email     full_name
# 0     Jane@email.com      Jane Doe
# 1    JohnD@email.com      John Doe
# 2  Dharani@email.com  Dharani Meka

# %%
df1['full_name'].str.split(' ')
# Out:
# 0        [Jane, Doe]
# 1        [John, Doe]
# 2    [Dharani, Meka]
# Name: full_name, dtype: object

# %%
df1[['first_name','last_name']] = df1['full_name'].str.split(' ',expand=True)

# %%
df1
# Out:
#                email     full_name first_name last_name
# 0     Jane@email.com      Jane Doe       Jane       Doe
# 1    JohnD@email.com      John Doe       John       Doe
# 2  Dharani@email.com  Dharani Meka    Dharani      Meka

# %%
#Remove rows

# %%
df1.drop(index=0)
# Out:
#                email     full_name first_name last_name
# 1    JohnD@email.com      John Doe       John       Doe
# 2  Dharani@email.com  Dharani Meka    Dharani      Meka

# %%
df1['full_name'] = df1['first']+' '+df1['last']

# %% [markdown]
# STACK OVERFLOW DATA

# %%
df=pd.read_csv('Data/survey_results_public.csv',index_col='Respondent')
schema_df = pd.read_csv("Data/survey_results_schema.csv",index_col='Column')

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
pd.set_option('display.max_columns',85)

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'}, inplace=True)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
 df['Hobbyist'] = df['Hobbyist'].map({'Yes':'True', 'No':'False'})

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code     True
# 2                      I am a student who is learning to code    False
# 3           I am not primarily a developer, but I write co...     True
# 4                              I am a developer by profession    False
# 5                              I am a developer by profession     True
# ...                                                       ...      ...
# 88377                                                     NaN     True
# 88601                                                     NaN    False
# 88802                                                     NaN    False
# 88816                                                     NaN    False
# 88863                                                     NaN     True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df['Hobbyist'] = df['Hobbyist'].replace({'Yes':'True', 'No':'False'})

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code     True
# 2                      I am a student who is learning to code    False
# 3           I am not primarily a developer, but I write co...     True
# 4                              I am a developer by profession    False
# 5                              I am a developer by profession     True
# ...                                                       ...      ...
# 88377                                                     NaN     True
# 88601                                                     NaN    False
# 88802                                                     NaN    False
# 88816                                                     NaN    False
# 88863                                                     NaN     True
#
#                                                   OpenSourcer  \
# Respondent
# ...
